# %%
import pandas as pd
import numpy as np
import astropy.units as u
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from pixel_table import PixelTable
from tools import ProgressBarCounter
from pixel_table_image_handler import ImageHandler
from multiprocessing import Pool

# %%
EL_SAUCE = EarthLocation(lat=-30.4726064*u.deg, lon=-70.7653747*u.deg, height=789*u.m)
utcoffset = -4*u.hour  # Chile
# time = Time('2018-6-13 07:26:12') #- utcoffset

# %%
def load_catalog(path, time):
    alt_az_frame = AltAz(obstime=time,location=EL_SAUCE)
    raw_data = []
    header = ["star_name", "Vmag", "ra", "dec", "alt", "az", "astropy_coords", "astropy_altaz"]
    with open(path, "r", encoding="utf-8") as file:
        for line in file:
            if line.replace("\n","")[75:77] != "  ":
                star_name = line.replace("\n","")[4:14]
                RAh = line.replace("\n","")[75:77]
                RAm = line.replace("\n","")[77:79]
                RAs = line.replace("\n","")[79:83]
                DE_sign = line.replace("\n","")[83]
                DE_deg = line.replace("\n","")[84:86]
                DE_arcmin = line.replace("\n","")[86:88]
                DE_arcseg = line.replace("\n","")[88:90]
                Vmag = float(line.replace("\n","")[102:107])
                
                ra = '{}h{}m{}s'.format(RAh,RAm, RAs)
                dec = "{}{}d{}m{}s".format(DE_sign, DE_deg, DE_arcmin, DE_arcseg)
                c = SkyCoord(ra, dec, frame='icrs')
                c_altaz = c.transform_to(alt_az_frame)
                raw_data.append([star_name, Vmag, c.ra, c.dec, c_altaz.alt.value, c_altaz.az.value, c, c_altaz])
    data = pd.DataFrame(raw_data, columns = header)
    return data

# %%
def data_to_ra_dec(data):
    ra = '{}h{}m{}s'.format(data.RAh,data.RAm, data.RAs)
    dec = "{}{}d{}m{}s".format(data.DE_sign, data.DE_deg, data.DE_arcmin, data.DE_arcseg)
    c = SkyCoord(ra, dec, frame='icrs')
    return c

# %%
def data_by_date(time):
    data = load_like_dataframe("bsc5.dat")
    alt_az_frame = AltAz(obstime=time,location=EL_SAUCE)
    data_processed = data.apply(lambda x: pd.Series(
                                            [x.star_name, x.Vmag, x.ra, x.dec, x.coords.transform_to(alt_az_frame).alt.value,
                                                                                    x.coords.transform_to(alt_az_frame).az.value,
                                                                                    x.coords, x.coords.transform_to(alt_az_frame)]
                                                    , index=["star_name", "Vmag", "ra", "dec", "alt", "az", "astropy_coords", "astropy_altaz"]
                                                    ), axis=1)
    return data_processed

# %%
df = load_catalog("bsc5.dat", Time("2019-9-07 04:00:56"))

# %%
df_best =  df.query("alt > 20 and Vmag < 6").sort_values("Vmag")
df_best

# %%
pixel_map = PixelTable("09-09-2019_22h58m04s_Interpolated_Data.pixtab")

# %%
pixel_map.df.dropna().query("(49.7 <= az <= 50.1) and (54.8 <= alt <= 55.2)").sort_values("alt")

# %%
best_alt_az = ((pixel_map.df.dropna().alt - df_best.iloc[0].alt).abs() + (pixel_map.df.dropna().az - df_best.iloc[0].az).abs())

# %%
pixel_map.df.iloc[best_alt_az.idxmin()]

# %%
def find_nearest_pixel(data, df_pixtab):
    best_alt_az = ((df_pixtab.dropna().alt - data.alt).abs()
                       + (df_pixtab.dropna().az - data.az).abs())
    return pixel_map.df.iloc[best_alt_az.idxmin()]

# %%
find_nearest_pixel(df_best.iloc[0], pixel_map.df)

# %%
df_best.iloc[0]

# %%
def catalogue_on_pixtab(catalogue_df, df_pixtab):
    pb = ProgressBarCounter(catalogue_df.shape[0])
    pixtab_out = pd.DataFrame()
    for indx in catalogue_df.index:
        nearest_pixel = find_nearest_pixel(catalogue_df.loc[indx], df_pixtab)
        pixtab_out = pd.concat([pixtab_out, nearest_pixel], axis=0, ignore_index = True)
        pb.notify()
    return pixtab_out

# %%
new_pix = catalogue_on_pixtab(df_best, pixel_map.df)

# %%
preview = ImageHandler(new_pix)

# %%
# def gen_worker_args(catalogue_df, df_pixtab, *args, **kwargs):
#     pbar = ProgressBarCounter(catalogue_df.shape[0])
#     for indx in catalogue_df.index:
#         yield (catalogue_df.loc[indx], df_pixtab, pbar)

# %%
# def worker(args):
#     data, df_pixtab, pbar = args
#     nearest_pixel = find_nearest_pixel(data, df_pixtab)
#     pb.notify()
#     return nearest_pixel

# %%
# p = Pool(10)
# pixel_list = p.map(worker, gen_worker_args(df_best, pixel_map.df))
# p.close()
# p.join()
# pixel_list = pd.concat(pixel_list, axis=1, ignore_index=True).transpose

# %%
nearest_pixel1 = find_nearest_pixel(df_best.iloc[0], pixel_map.df).transpose()
nearest_pixel2 = find_nearest_pixel(df_best.iloc[1], pixel_map.df).transpose()

# %%
pd.concat([nearest_pixel1, nearest_pixel2, nearest_pixel], axis=1, ignore_index=True).transpose()

# %%
nearest_pixel

# %%
from catalog_handler import Catalog, CatalogPreview
from astropy.time import Time
from pixel_table import PixelTable

# %%
catalog = Catalog("bsc5.dat", Time("2019-9-07 04:00:56"))
# Out:
# Cargando catalogo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8e53e3c15f19> in <module>
# ----> 1 catalog = Catalog("bsc5.dat", Time("2019-9-07 04:00:56"))
#
# D:\Karlos\Universidad\Investigación\my-chacana\Zoc\catalog_handler.py in __init__(self, path, time)
#      23     def __init__(self, path, time):
#      24         print("Cargando catalogo")
# ---> 25         df = self.load_catalog(path, time)
#      26         self.df = df.query(BEST_QUERY).sort_values("Vmag")
#      27         print("Exito...")
#
# D:\Karlos\Universidad\Investigación\my-chacana\Zoc\catalog_handler.py in load_catalog(self, path, time)
#      47                     dec = "{}{}d{}m{}s".format(DE_sign, DE_deg, DE_arcmin, DE_arcseg)
#      48                     c = SkyCoord(ra, dec, frame='icrs')
# ---> 49                     c_altaz = c.transform_to(alt_az_frame)
#      50                     raw_data.append([star_name, Vmag, c.ra, c.dec, c_altaz.alt.value, c_altaz.az.value, c, c_altaz])
#      51         data = pd.DataFrame(raw_data, columns = header)
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\coordinates\sky_coordinate.py in transform_to(self, frame, merge_attributes)
#     439         # Do the transformation, returning a coordinate frame of the desired
#     440         # final type (not generic).
# --> 441         new_coord = trans(self.frame, generic_frame)
#     442
#     443         # Finally make the new SkyCoord object from the `new_coord` and
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\coordinates\transformations.py in __call__(self, fromcoord, toframe)
#    1375
#    1376             curr_toframe = t.tosys(**frattrs)
# -> 1377             curr_coord = t(curr_coord, curr_toframe)
#    1378
#    1379         # this is safe even in the case where self.transforms is empty, because
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\coordinates\transformations.py in __call__(self, fromcoord, toframe)
#     978             return reprwithoutdiff.realize_frame(reprwithdiff)
#     979         else:
# --> 980             return supcall(fromcoord, toframe)
#     981
#     982
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\coordinates\builtin_frames\icrs_cirs_transforms.py in icrs_to_cirs(icrs_coo, cirs_frame)
#      28     jd1, jd2 = get_jd12(cirs_frame.obstime, 'tdb')
#      29     x, y, s = get_cip(jd1, jd2)
# ---> 30     earth_pv, earth_heliocentric = prepare_earth_position_vel(cirs_frame.obstime)
#      31     astrom = erfa.apci(jd1, jd2, earth_pv, earth_heliocentric, x, y, s)
#      32
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\coordinates\builtin_frames\utils.py in prepare_earth_position_vel(time)
#     282     from ..solar_system import (get_body_barycentric, get_body_barycentric_posvel)
#     283     # get barycentric position and velocity of earth
# --> 284     earth_p, earth_v = get_body_barycentric_posvel('earth', time)
#     285
#     286     # get heliocentric position of earth, preparing it for passing to erfa.
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\coordinates\solar_system.py in get_body_barycentric_posvel(body, time, ephemeris)
#     328
#     329     """
# --> 330     return _get_body_barycentric_posvel(body, time, ephemeris)
#     331
#     332
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\coordinates\solar_system.py in _get_body_barycentric_posvel(body, time, ephemeris, get_velocity)
#     209         if ephemeris is None:
#     210             raise ValueError(_EPHEMERIS_NOTE)
# --> 211         kernel = solar_system_ephemeris.kernel
#     212     else:
#     213         kernel = _get_kernel(ephemeris)
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\utils\decorators.py in __get__(self, obj, objtype)
#     642         # instead we pass objtype through to the original wrapped
#     643         # function (which takes the class as its sole argument)
# --> 644         val = self.fget.__wrapped__(objtype)
#     645
#     646         if self._lazy:
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\astropy\coordinates\solar_system.py in kernel(cls)
#     127         return cls._kernel
#     128
# --> 129     @classproperty
#     130     def kernel(cls):
#     131         return cls.get_kernel(cls._value)
#
# KeyboardInterrupt:

# %%
pixtab = PixelTable("09-10-2019_05h10m24s_Interpolated_Data.pixtab")

# %%
catalog_pixtab = catalog.find_on_pixtab(pixtab.df)

# %%
preview = CatalogPreview(catalog_pixtab)

# %%
preview.save()

# %%
pixtab.preview.az
# Out:
# Creando vista previa de pixeles
# Progress: |--------------------------------------------------| 0.0% Complete
# Progress: |--------------------------------------------------| 0.0% Complete
# Progress: |--------------------------------------------------| 1.0% Complete
# Progress: |--------------------------------------------------| 1.0% Complete
# Progress: |--------------------------------------------------| 1.0% Complete
# Progress: |█-------------------------------------------------| 2.0% Complete
# Progress: |█-------------------------------------------------| 2.0% Complete
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Exito!

# %%
def mod_az(x):
    return x + 45 if (x + 45) < 360 else (x + 45)-360

# %%
pixtab.df["az"] = pixtab.df.az.apply(mod_az)

# %%
pixtab.preview = ImageHandler(pixtab.df)

# %%
pixtab.preview.az
# Out:
# Creando vista previa de pixeles
# Progress: |--------------------------------------------------| 0.0% Complete
# Progress: |--------------------------------------------------| 0.0% Complete
# Progress: |--------------------------------------------------| 1.0% Complete
# Progress: |--------------------------------------------------| 1.0% Complete
# Progress: |--------------------------------------------------| 1.0% Complete
# Progress: |█-------------------------------------------------| 2.0% Complete
# Progress: |█-------------------------------------------------| 2.0% Complete
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Exito!

# %%
pixtab.NAME = "Interpolated_Data_handcraft_2"

# %%
pixtab.export_to_file()
# Out:
# 1
