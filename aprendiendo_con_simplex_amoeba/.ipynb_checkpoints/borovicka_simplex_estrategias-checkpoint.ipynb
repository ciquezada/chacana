# %% [markdown]
# # Amoeba en Borovicka

# %%
from scipy import optimize, stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ## Funciones

# %%
"""
Funciones de Borovicka que
dependen de [C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0]
"""

def construct_radio(C, A, F, X0, Y0, a0):
    def r(x, y):
        return C * ( np.sqrt( (x-X0)**2 + (y-Y0)**2 ) + A*(y-X0)*np.cos(F-a0) - A*(x-X0)*np.sin(F-a0) )
    return r

def construct_u(C, A, F, V, S, D, P, Q, X0, Y0, a0):
    def u(x, y):
        r = construct_radio(C, A, F, X0, Y0, a0)
        return V*r(x, y) + S*(np.e**(D*r(x,y)) - 1) + P*(np.e**(Q*r(x,y)**2) - 1) 
    return u

def construct_b(E, X0, Y0, a0):
    def b(x, y):
        return a0 - E + np.arctan2((y - Y0),(x - X0))
    return b

def construct_altura(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0):
    def z(x, y):
        u = construct_u(C, A, F, V, S, D, P, Q, X0, Y0, a0)
        b = construct_b(E, X0, Y0, a0)
        return np.arccos( np.cos(u(x,y))*np.cos(ep) - np.sin(u(x,y))*np.sin(ep)*np.cos(b(x,y)) )
    return z

def construct_altura_deg(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0):
    def z(x, y):
        u = construct_u(C, A, F, V, S, D, P, Q, X0, Y0, a0)
        b = construct_b(E, X0, Y0, a0)
        return 90 - np.rad2deg( np.arccos( np.cos(u(x,y))*np.cos(ep) - np.sin(u(x,y))*np.sin(ep)*np.cos(b(x,y)) ) )
    return z

def construct_azimuth(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0):
    def az(x, y):
        u = construct_u(C, A, F, V, S, D, P, Q, X0, Y0, a0)
        b = construct_b(E, X0, Y0, a0)
        z = construct_altura(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0)
        return np.arcsin( np.sin(b(x,y))*np.sin(u(x,y))/np.sin(z(x,y)) ) + E
    return az

def construct_azimuth_deg(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0):
    def az(x, y):
        u = construct_u(C, A, F, V, S, D, P, Q, X0, Y0, a0)
        b = construct_b(E, X0, Y0, a0)
        z = construct_altura(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0)
        return np.rad2deg( np.arcsin( np.sin(b(x,y))*np.sin(u(x,y))/np.sin(z(x,y)) ) + E ) + 90
    return az

"""
Estos son constructores de una funcion de Xi**2
"""

def construct_alt_xi(x, y, z):
    def xi(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0):
        alt_teorico = construct_altura_deg(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0)
        return (z - alt_teorico(x, y))**2
    return xi

def construct_az_xi(x, y, z):
    def xi(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0):
        az_teorico = construct_azimuth_deg(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0)
        return (z - az_teorico(x, y))**2
    return xi

# %%
"""
Para reducir los datos outlayers segun que tan lejos quedan de la primera
aproximacion por Borovicka
"""
def drop_outlayers_by_borovicka(pixtab_df, plano, diff = 1):
    
    X_MIN = 250
    X_MAX = 1250
    Y_MIN = 0
    Y_MAX = 950
    MAX_RADIO = 500
    RADIO_STEPS = 2000
    query_str = "{}<=x<={} and {}<=y<={}".format(X_MIN, X_MAX,
                                                            Y_MIN, Y_MAX)
    data = pixtab_df.dropna(thresh = 7).query(query_str)
    
    pbar = tqdm(total=len(data.x.values), desc="Droping Outlayers")
    new_df_indx = []
    for indx in data.index:
        x = data.at[indx,"x"]
        y = data.at[indx,"y"]
        alt = data.at[indx,"alt"]
        if np.abs(plano(x,y)-alt) < diff:
            new_df_indx.append(indx)
        pbar.update()
    return data.loc[new_df_indx]

# Por si queremos exportar los datos para visualizarlos 
# out = drop_outlayers_by_borovicka(data, X0, Y0)
# out
# out["xcentroid"] = out["x"]
# out["ycentroid"] = out["y"]
# out.to_csv("drop_outlayer.dat", sep=' ', index=False)
# plt.gca().invert_yaxis()
# plt.scatter(out.x.values, out.y.values, c=out.alt.values, s=0.01)

# %%
"""
Para plotear la altura o el azimut, es necesaria
una lista con todos los parametros 
[C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0]
"""

def plot_plano(plano):
    x = np.linspace(0, 1200, 100)
    y = np.linspace(0, 900, 100)
    X, Y = np.meshgrid(x, y)
    Z = plano(X, Y)
    fig,ax=plt.subplots(1,1)
    cp = ax.contourf(X, Y, Z, 10)
    fig.colorbar(cp) # Add a colorbar to a plot
    ax.set_title('Toda una linea que minimiza y=mx+n')
    plt.gca().invert_yaxis()
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    plt.show()

def plot_altura(vector):
    plano = construct_altura_deg(*vector)
    plot_plano(plano)
    
def plot_azimuth(vector):
    plano = construct_azimuth_deg(*vector)
    plot_plano(plano)

# %%
"""
Esto lo definimos por cada intento segun los parametros constantes que
queramos dejar
"""

def construct_acumulate_alt_xi(x_list, y_list, z_list, ctes = None):
    def acumulate_xi(params):
        V, S, D, P, Q, a0 = ctes
        C, A, F, E, ep, X0, Y0 = params
        suma_xi = 0
        for x, y, z in zip(x_list, y_list, z_list):
            xi = construct_alt_xi(int(x), int(y), int(z))
            suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
        pbar.update()
        return suma_xi
    return acumulate_xi

def construct_acumulate_az_xi(x_list, y_list, z_list, ctes = None):
    def acumulate_xi(params):
        V, S, D, P, Q, a0 = ctes
        C, A, F, E, ep, X0, Y0 = params
        suma_xi = 0
        for x, y, z in zip(x_list, y_list, z_list):
            xi = construct_az_xi(int(x), int(y), int(z))
            suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
        pbar.update()
        return suma_xii
    return acumulate_xi

######################################################################################################

def amoeba(params, mega_alt_xi, mega_az_xi):
    new_alt_params = optimize.fmin(mega_alt_xi, params, maxfun=1100)
    new_az_params = optimize.fmin(mega_az_xi, params, maxfun=1100)
    return [new_alt_params, new_az_params]

# %% [markdown]
# ## Reduction types:
#
# There are many types as mentioned in the section 2.2.3. of the paper.
# However, IRED may be zero when entering REDSKY. Then the standard
# reduction type 314 is used. The most usual types are
#
# 314 - V,S,D,P,Q kept at their standard values, other constants computed
#
# 334 - P,Q kept, C=1, other computed
#
# 354 - C=1, other computed (requires stars close to horizon)
#
# 311 - as 314 but A=0, F=0 (similarly 331, 351)
#
# 310 - as 311 but also epsilon=0, E=0 (similarly 330, 350) ([V,S,D,P,Q]=ctes, [A,F,E,ep]=0, solo se busca C)
#
# 319 - as 314 but epsilon,E,A,F kept at their initial values (similarly
#       339, 359) ([V,S,D,P,Q,A,F,E,ep]=ctes solo se busca C)

# %% [markdown]
# ## Algunos parametros conocidos
# C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0 :
#
#
# - <sub> $Xi^2=2.206$ : [0.04884978986903654, 0.020304825896093035, 0.35248628545828664, 0.0682171007, 0.00310608468, -5.75141386e-05, 4.26865327e-06, -0.00415889519, 0.005383738310580881, 0.0014950622892165601, 724, 472, -3*np.pi/4]
#
# - <sub>  $Xi^2=2.154$ : [4.37875766e-02,  5.19853314e-03,  1.05416567e+00,  7.33610329e-02, -5.24112025e-02, -1.39156740e-01,  4.41635759e-03,  4.71369350e-03, 2.74820813e+00, -1.02665758e-01, 731, 506, -0.582*np.pi]
#
# Encontrados ahora:
# - [1)](#section1) <sub> $Xi^2=2.210$ : [0.048826087003725455, -0.021142174069559417, 0.32598730818211297, 0.0682171007, 0.00310608468, -5.75141386e-05, 4.26865327e-06, -0.00415889519, 0.08741648813678929, -0.0022711518934522366, 724, 472, np.pi/4]
#
# - [2)](#section2) <sub> $Xi^2=2.246$ : [0.048826087003725455, -0.021142174069559417, 0.32598730818211297, 0.0682171007, 0.00310608468, -5.75141386e-05, 4.26865327e-06, -0.00415889519, 0.08741648813678929, -0.0022711518934522366, 724.59618727, 472.68750979, np.pi/4]
#
# - [3)](#section3) <sub> $Xi^2_{alt}=2.228$, $Xi^2_{az}=60.30$ : [0.048826087003725455, -0.021142174069559417, 0.32598730818211297, 0.0682171007, 0.00310608468, -5.75141386e-05, 4.26865327e-06, -0.00415889519, 0.08741648813678929, -0.0022711518934522366, 724.59618727, 472.68750979, 0.82635545]
#
# - [4)](#section4) <sub> $Xi^2_{alt}=2.205$, $Xi^2_{az}=20.94$ : [0.048826087003725455, -0.021142174069559417, 0.32598730818211297, 0.0682171007, 0.00310608468, -5.75141386e-05, 4.26865327e-06, -0.00415889519, -0.0298275, -0.0022711518934522366, 724, 472, 0.75060687]
#
# - [5)](#section5) <sub> $Xi^2_{alt}=3.120$, $Xi^2_{az}=15.75$ : [0.048826087003725455, -0.021142174069559417, 0.32598730818211297, 0.0682171007, 0.00310608468, -5.75141386e-05, 4.26865327e-06, -0.00415889519, -4.82552710e-03, -0.0022711518934522366, 7.28125200e+02,  4.78181845e+02, 7.73853421e-01]
#
# - [6)](#section6) <sub> $Xi^2_{alt}=2.320$, $Xi^2_{az}=15.75$ : [0.04952671,  0.00310034, -1.04782185, 0.0682171007, 0.00310608468, -5.75141386e-05, 4.26865327e-06, -0.00415889519, -4.82552710e-03, -0.0022711518934522366, 7.28125200e+02,  4.78181845e+02, 7.73853421e-01]
#
# - [7)](#section7) <sub> $Xi^2_{alt}=2.236$, $Xi^2_{az}=15.75$ : [0.04952671,  0.00310034, -1.04782185, 9.61696411e-02, -3.11311558e+00,  8.47643783e-03,  5.83185714e-04, 7.66455100e-03, -4.82552710e-03, -0.0022711518934522366, 7.28125200e+02,  4.78181845e+02, 7.73853421e-01]
#
# - [8)](#section8) <sub> $Xi^2_{alt}=2.142$, $Xi^2_{az}=15.89$ : [0.04933449,  0.00478405, -0.1298804, 9.61696411e-02, -3.11311558e+00,  8.47643783e-03,  5.83185714e-04, 7.66455100e-03, -4.82552710e-03, -0.0022711518934522366, 7.28125200e+02,  4.78181845e+02, 7.73853421e-01]
#
# - [9)](#section9) <sub> $Xi^2_{alt}=2.147$, $Xi^2_{az}=15.89$ : [0.04933449,  0.00478405, -0.1298804, 9.44302225e-02, -3.90770908e+00,  6.47675936e-03,  1.99616127e-03, 5.31560995e-03, -4.82552710e-03, -0.0022711518934522366, 7.28125200e+02,  4.78181845e+02, 7.73853421e-01]
#
#
# Facts:
# - mover ep reduciendo azimut es super peligroso
# - hay que sumarle 90 al azimuth porque borovicka lo tiene entre \[-90,90\]
# - E no solo rota, si no, que tambien ensancha o agudiza el espacio que ocupan los grados
# - mover E,X0,Y0,a0 juntos reduciendo azimuth es muy bueno para encontrar el centro
# - mover V,S,D,P,Q no afecta al azimuth!
#
#
#
# [Greedy](#greedy) Intentamos reducir altura y azimut al mismo tiempo,
# los paramtros iniciales fueron los obtenidos en 6

# %% [markdown]
# [subir](#index)<a id='pipeline'></a>
# ## Intentemos un pipeline

# %% [markdown]
# Solo podriamos conocer un V,S,D,P,Q aproximado dado del paper de Borovicka. Ademas sobre C,A,F podemos seguir el consejo de hacer A,F nulos, pero C tendra que ser un valor pequeño como 0.01. Para E,ep podemos hacerlos nulos. El centro X0,Y0 tendremos que aporximarlo al ojo, tener una idea, en este caso 724,472. Por ultimo el offset del azimut a0 podemos hacerlo nulo.
#
# Parametros iniciales:
# - [0)] <sub> $Xi^2_{alt}=2.142$, $Xi^2_{az}=15.89$ : [0.01, 0, 0, 0.03, 0.007, 0.09, 2.2e-06, 0.006, 0, 0, 724, 472, 0]

# %%
results_list = []

# %% [markdown]
# ### Paso 1
# Primero haremos un acercamiento 314 para buscar parametros C,A,F,E,ep que nos ayuden a reducir mejor los datos outlayers
#
# Otra opcion era buscar E,X0,Y0,a0 desde el principio sin quitar datos outlayers, el problema es que E,ep al ser 0 tienen problemas en la funcion de azimut

# %%
"""
314 - V, S, D, P, Q, X0, Y0, a0
"""

def construct_acumulate_alt_xi(x_list, y_list, z_list, ctes = None):
    def acumulate_xi(params):
        V, S, D, P, Q, X0, Y0, a0 = ctes
        C, A, F, E, ep, = params
        suma_xi = 0
        for x, y, z in zip(x_list, y_list, z_list):
            xi = construct_alt_xi(int(x), int(y), int(z))
            suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
        pbar.update()
        return suma_xi
    return acumulate_xi

def construct_acumulate_az_xi(x_list, y_list, z_list, ctes = None):
    def acumulate_xi(params):
        V, S, D, P, Q, X0, Y0, a0 = ctes
        C, A, F, E, ep, = params
        suma_xi = 0
        for x, y, z in zip(x_list, y_list, z_list):
            xi = construct_az_xi(int(x), int(y), int(z))
            suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
        pbar.update()
        return suma_xi
    return acumulate_xi

######################################################################################################

def amoeba(params, mega_alt_xi, mega_az_xi):
    new_alt_params = optimize.fmin(mega_alt_xi, params, maxfun=1100)
#     new_az_params = optimize.fmin(mega_az_xi, params, maxfun=1100)
    return [new_alt_params]

init_params = [0.01, 0, 0, 0, 0]
ctes = [0.03, 0.007, 0.09, 2.2*10**-6, 0.006,
           724, 472, 0]

data = pd.read_csv("Data.pixtab", sep=" ")
data = data.dropna()
data = drop_outlayers_by_borovicka(data, construct_altura_deg(*init_params[:3], *ctes[:-3], *init_params[-2:], *ctes[-3:]), 5)
x_exp = data.x.values
y_exp = data.y.values
alt_catalogo = data.alt.values
az_catalogo = np.rad2deg(np.arccos(np.cos(np.deg2rad(data.az.values))))
mega_alt_xi = construct_acumulate_alt_xi(x_exp, y_exp, alt_catalogo, ctes)
mega_az_xi = construct_acumulate_az_xi(x_exp, y_exp, az_catalogo, ctes)

pbar = tqdm(total=2200, desc="Aproximando altura y azimuth")
results_list += amoeba(init_params, mega_alt_xi, mega_az_xi)
pbar.close()
results_list[-1]

result_1 = [*results_list[-1][:3], *ctes[:-3], *results_list[-1][-2:], *ctes[-3:]]
result_1
# Out:
# Droping Outlayers:   0%|                                                                     | 0/80771 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   1%|▌                                                        | 841/80771 [00:00<00:09, 8330.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   2%|█▏                                                      | 1673/80771 [00:00<00:09, 8317.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   3%|█▋                                                      | 2503/80771 [00:00<00:09, 8294.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   4%|██▎                                                     | 3340/80771 [00:00<00:09, 8298.57it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   5%|██▉                                                     | 4184/80771 [00:00<00:09, 8322.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   6%|███▍                                                    | 5014/80771 [00:00<00:09, 8311.70it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   7%|████                                                    | 5846/80771 [00:00<00:09, 8306.92it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   8%|████▌                                                   | 6661/80771 [00:00<00:08, 8253.19it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   9%|█████▏                                                  | 7501/80771 [00:00<00:08, 8279.48it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  10%|█████▊                                                  | 8343/80771 [00:01<00:08, 8302.47it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  11%|██████▎                                                 | 9158/80771 [00:01<00:08, 8238.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  12%|██████▉                                                 | 9988/80771 [00:01<00:08, 8238.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  13%|███████▎                                               | 10823/80771 [00:01<00:08, 8254.22it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  14%|███████▉                                               | 11666/80771 [00:01<00:08, 8287.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  15%|████████▌                                              | 12506/80771 [00:01<00:08, 8303.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  17%|█████████                                              | 13345/80771 [00:01<00:08, 8310.82it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  18%|█████████▋                                             | 14190/80771 [00:01<00:07, 8333.29it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  19%|██████████▏                                            | 15022/80771 [00:01<00:07, 8310.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  20%|██████████▊                                            | 15860/80771 [00:01<00:07, 8313.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  21%|███████████▎                                           | 16697/80771 [00:02<00:07, 8325.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  22%|███████████▉                                           | 17533/80771 [00:02<00:07, 8335.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:
#      34     return [new_alt_params]
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     407             'initial_simplex': initial_simplex}
#     408
# --> 409     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     410     if full_output:
#     411         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     566         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     567         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 568         fxr = func(xr)
#     569         doshrink = 0
#     570
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# <ipython-input-123-ade1fed06c5d> in acumulate_xi(params)
#      10         for x, y, z in zip(x_list, y_list, z_list):
#      11             xi = construct_alt_xi(int(x), int(y), int(z))
# ---> 12             suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
#      13         pbar.update()
#      14         return suma_xi
#
# <ipython-input-51-d75031252e27> in xi(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0)
#      57     def xi(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0):
#      58         alt_teorico = construct_altura_deg(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0)
# ---> 59         return (z - alt_teorico(x, y))**2
#      60     return xi
#      61
#
# <ipython-input-51-d75031252e27> in z(x, y)
#      31         u = construct_u(C, A, F, V, S, D, P, Q, X0, Y0, a0)
#      32         b = construct_b(E, X0, Y0, a0)
# ---> 33         return 90 - np.rad2deg( np.arccos( np.cos(u(x,y))*np.cos(ep) - np.sin(u(x,y))*np.sin(ep)*np.cos(b(x,y)) ) )
#      34     return z
#      35
#
# <ipython-input-51-d75031252e27> in u(x, y)
#      12     def u(x, y):
#      13         r = construct_radio(C, A, F, X0, Y0, a0)
# ---> 14         return V*r(x, y) + S*(np.e**(D*r(x,y)) - 1) + P*(np.e**(Q*r(x,y)**2) - 1)
#      15     return u
#      16
#
# <ipython-input-51-d75031252e27> in r(x, y)
#       6 def construct_radio(C, A, F, X0, Y0, a0):
#       7     def r(x, y):
# ----> 8         return C * ( np.sqrt( (x-X0)**2 + (y-Y0)**2 ) + A*(y-X0)*np.cos(F-a0) - A*(x-X0)*np.sin(F-a0) )
#       9     return r
#      10
#
# KeyboardInterrupt:

# %% [markdown]
# ### Paso 2
# Primero haremos un acercamiento 314 para buscar parametros C,A,F,E,ep que nos ayuden a reducir mejor los datos outlayers
#
# Otra opcion era buscar E,X0,Y0,a0 desde el principio sin quitar datos outlayers, el problema es que E,ep al ser 0 tienen problemas en la funcion de azimut

# %% [markdown]
# # Desarrollo

# %%
"""
314 - V, S, D, P, Q, X0, Y0, a0
"""

def construct_acumulate_alt_xi(x_list, y_list, z_list, ctes = None):
    def acumulate_xi(params):
        V, S, D, P, Q, X0, Y0, a0 = ctes
        C, A, F, E, ep, = params
        suma_xi = 0
        for x, y, z in zip(x_list, y_list, z_list):
            xi = construct_alt_xi(int(x), int(y), int(z))
            suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
        pbar.update()
        return suma_xi
    return acumulate_xi

def construct_acumulate_az_xi(x_list, y_list, z_list, ctes = None):
    def acumulate_xi(params):
        V, S, D, P, Q, X0, Y0, a0 = ctes
        C, A, F, E, ep, = params
        suma_xi = 0
        for x, y, z in zip(x_list, y_list, z_list):
            xi = construct_az_xi(int(x), int(y), int(z))
            suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
        pbar.update()
        return suma_xi
    return acumulate_xi

######################################################################################################

def amoeba(params, mega_alt_xi, mega_az_xi):
    new_alt_params = optimize.fmin(mega_alt_xi, params, maxfun=1100)
#     new_az_params = optimize.fmin(mega_az_xi, params, maxfun=1100)
    return [new_alt_params]

# %%
init_params = [0.01, 0, 0, 0, 0]
ctes = [0.03, 0.007, 0.09, 2.2*10**-6, 0.006,
           724, 472, 0]

data = pd.read_csv("Data.pixtab", sep=" ")
data = data.dropna()
data = drop_outlayers_by_borovicka(data, construct_altura_deg(*init_params[:3], *ctes[:-3], *init_params[-2:], *ctes[-3:]), 5)
x_exp = data.x.values
y_exp = data.y.values
alt_catalogo = data.alt.values
az_catalogo = np.rad2deg(np.arccos(np.cos(np.deg2rad(data.az.values))))
mega_alt_xi = construct_acumulate_alt_xi(x_exp, y_exp, alt_catalogo, ctes)
mega_az_xi = construct_acumulate_az_xi(x_exp, y_exp, az_catalogo, ctes)
results_list = []
# Out:
# Droping Outlayers:   0%|                                                                     | 0/80771 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   1%|▌                                                        | 831/80771 [00:00<00:09, 8249.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   2%|█▏                                                      | 1675/80771 [00:00<00:09, 8287.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   3%|█▋                                                      | 2505/80771 [00:00<00:09, 8273.60it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   4%|██▎                                                     | 3342/80771 [00:00<00:09, 8284.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   5%|██▉                                                     | 4187/80771 [00:00<00:09, 8315.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   6%|███▍                                                    | 5016/80771 [00:00<00:09, 8289.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   7%|████                                                    | 5862/80771 [00:00<00:09, 8322.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   8%|████▋                                                   | 6690/80771 [00:00<00:08, 8290.97it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:   9%|█████▏                                                  | 7533/80771 [00:00<00:08, 8314.18it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  10%|█████▊                                                  | 8375/80771 [00:01<00:08, 8327.56it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  11%|██████▍                                                 | 9217/80771 [00:01<00:08, 8336.87it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  12%|██████▊                                                | 10053/80771 [00:01<00:08, 8325.81it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  13%|███████▍                                               | 10893/80771 [00:01<00:08, 8330.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  15%|███████▉                                               | 11739/80771 [00:01<00:08, 8350.16it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  16%|████████▌                                              | 12580/80771 [00:01<00:08, 8349.56it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:  17%|█████████▏                                             | 13428/80771 [00:01<00:08, 8370.23it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Droping Outlayers:
24it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:   9%|████▌                                            | 204/2200 [00:05<00:53, 37.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:   9%|████▋                                            | 208/2200 [00:05<00:53, 37.16it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  10%|████▋                                            | 212/2200 [00:05<00:53, 36.85it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  10%|████▊                                            | 216/2200 [00:05<00:53, 36.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  10%|████▉                                            | 220/2200 [00:05<00:53, 36.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  10%|████▉                                            | 224/2200 [00:05<00:54, 36.53it/s]
# Aproximando altura y azimuth:  10%|█████                                            | 228/2200 [00:06<00:53, 36.61it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  11%|█████▏                                           | 232/2200 [00:06<00:53, 36.97it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  11%|█████▎                                           | 236/2200 [00:06<00:53, 37.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  11%|█████▎                                           | 240/2200 [00:06<00:52, 37.15it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  11%|█████▍                                           | 244/2200 [00:06<00:52, 37.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  11%|█████▌                                           | 248/2200 [00:06<00:52, 37.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  11%|█████▌                                           | 252/2200 [00:06<00:52, 36.91it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  12%|█████▋                                           | 256/2200 [00:06<00:52, 37.19it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  12%|█████▊                                           | 260/2200 [00:06<00:52, 37.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  12%|█████▉                                           | 264/2200 [00:07<00:52, 36.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  12%|█████▉                                           | 268/2200 [00:07<00:52, 36.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  12%|██████                                           | 272/2200 [00:07<00:52, 37.00it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  13%|██████▏                                          | 276/2200 [00:07<00:51, 37.04it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  13%|██████▏                                          | 280/2200 [00:07<00:51, 37.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  13%|██████▎                                          | 284/2200 [00:07<00:51, 37.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  13%|██████▍                                          | 288/2200 [00:07<00:51, 37.08it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  13%|██████▌                                          | 292/2200 [00:07<00:51, 37.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  13%|██████▌                                          | 296/2200 [00:07<00:51, 37.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  14%|██████▋                                          | 300/2200 [00:08<00:50, 37.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  14%|██████▊                                          | 304/2200 [00:08<00:50, 37.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  14%|██████▊                                          | 308/2200 [00:08<00:51, 37.02it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  14%|██████▉                                          | 312/2200 [00:08<00:50, 37.15it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:  14%|███████                                          | 316/2200 [00:08<00:50, 37.24it/s]
# Optimization terminated successfully.
#          Current function value: 127.568683
#          Iterations: 191
#          Function evaluations: 317
# Aproximando altura y azimuth:  14%|███████                                          | 317/2200 [00:08<00:50, 37.31it/s]
# array([ 0.09935315, -0.03387904, -0.04467695,  0.01311418, -0.00192129])
# Droping Outlayers: 100%|███████████████████████████████████████████████████████| 80771/80771 [00:25<00:00, 8269.51it/s]

# %%
result_3 = (0.09935315, -0.03387904, -0.04467695,
             0.03, 0.007, 0.09, 2.2*10**-6, 0.006,
            0.01311418, -0.00192129, 724, 472, 0)
plot_altura(result_3)
plot_azimuth(result_3)

# %%
data = pd.read_csv("Data.pixtab", sep=" ")
data = data.dropna()
# data = drop_outlayers_by_borovicka(data, construct_altura_deg(*init_params[:3], *ctes[:-3], *init_params[-2:], *ctes[-3:]), 5)
x_exp = data.x.values
y_exp = data.y.values
alt_catalogo = data.alt.values
az_catalogo = np.rad2deg(np.arccos(np.cos(np.deg2rad(data.az.values))))
mega_alt_xi = construct_acumulate_alt_xi(x_exp, y_exp, alt_catalogo, ctes)
mega_az_xi = construct_acumulate_az_xi(x_exp, y_exp, az_catalogo, ctes)

old_params = np.array([0.01, 0, 0, 0, 0])
new_params = np.array([0.09935315, -0.03387904, -0.04467695,  0.01311418, -0.00192129])
(mega_alt_xi(old_params)/len(x_exp), mega_alt_xi(new_params)/len(x_exp))
# Out:
# (2609.070457063858, 173.7964574349717)

# %%
plt.gca().invert_yaxis()
plt.scatter(x_exp, y_exp, c=az_catalogo, s=0.01)

# %%
data
# Out:
#            x    y       alt          az    alt_err    az_err  sample_size
# 123016   724   79  1.091931  305.393290  12.396973  9.451602            2
# 123026   734   79 -1.378658  303.488430  12.677556  9.384614            7
# 123027   735   79  4.284897  307.769736  11.940170  8.868728            3
# 124572   732   80  0.861730  305.124822  12.881579  9.578923            6
# 124573   733   80  0.586913  304.972775  12.755659  9.507580            4
# ...      ...  ...       ...         ...        ...       ...          ...
# 1325661  573  856  6.872654  110.742898   1.199879  0.928168            2
# 1325662  574  856  6.942214  110.701613   1.199774  0.928882            2
# 1327210  574  857  6.664805  110.866623   1.204371  0.927984           12
# 1327211  575  857  6.459436  110.989222   1.200352  0.923927            2
# 1328761  577  858  7.277818  111.056431   1.716538  0.754962            3
#
# [59709 rows x 7 columns]
# Droping Outlayers: 100%|██████████████████████████████████████████████████████| 80771/80771 [00:21<00:00, 10043.48it/s]

# %%
"""
311 - C, A, F, V, S, D, P, Q, ep, a0
"""

def construct_acumulate_alt_xi(x_list, y_list, z_list, ctes = None):
    def acumulate_xi(params):
        C, A, F, V, S, D, P, Q, ep = ctes
        E, X0, Y0, a0, = params
        suma_xi = 0
        for x, y, z in zip(x_list, y_list, z_list):
            xi = construct_alt_xi(int(x), int(y), int(z))
            suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
        pbar.update()
        return suma_xi
    return acumulate_xi

def construct_acumulate_az_xi(x_list, y_list, z_list, ctes = None):
    def acumulate_xi(params):
        C, A, F, V, S, D, P, Q, ep = ctes
        E, X0, Y0, a0, = params
        suma_xi = 0
        for x, y, z in zip(x_list, y_list, z_list):
            xi = construct_az_xi(int(x), int(y), int(z))
            suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
        pbar.update()
        return suma_xi
    return acumulate_xi

######################################################################################################

def amoeba(params, mega_alt_xi, mega_az_xi):
#     new_alt_params = optimize.fmin(mega_alt_xi, params, maxfun=1100)
    new_az_params = optimize.fmin(mega_az_xi, params, maxfun=1100)
    return [new_az_params]

# %%
init_params = [0, 724, 472, 0]
ctes = [0.01, 0, 0,
         0.03, 0.007, 0.09, 2.2*10**-6, 0.006,
         0]

data = pd.read_csv("Data.pixtab", sep=" ")
data = data.dropna()
# data = drop_outlayers_by_borovicka(data, construct_altura_deg(*ctes[:-1], init_params[0], ctes[-1], *init_params[-3:]), 5)
x_exp = data.x.values
y_exp = data.y.values
alt_catalogo = data.alt.values
az_catalogo = np.rad2deg(np.arccos(np.cos(np.deg2rad(data.az.values))))
mega_alt_xi = construct_acumulate_alt_xi(x_exp, y_exp, alt_catalogo, ctes)
mega_az_xi = construct_acumulate_az_xi(x_exp, y_exp, az_catalogo, ctes)
results_list = []

# %%
pbar = tqdm(total=1100, desc="Aproximando altura y azimuth")
results_list += amoeba(init_params, mega_alt_xi, mega_az_xi)
pbar.close()
results_list[-1]
# Out:
# Aproximando altura y azimuth:   0%|                                                           | 0/1100 [00:00<?, ?it/s]c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in arcsin
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in double_scalars
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aproximando altura y azimuth:   0%|                                                 | 1/1100 [00:07<2:14:59,  7.37s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-116-cd8fb833c9eb> in <module>
#       1 pbar = tqdm(total=1100, desc="Aproximando altura y azimuth")
# ----> 2 results_list += amoeba(init_params, mega_alt_xi, mega_az_xi)
#       3 pbar.close()
#       4 results_list[-1]
#
# <ipython-input-112-263c11289320> in amoeba(params, mega_alt_xi, mega_az_xi)
#      31 def amoeba(params, mega_alt_xi, mega_az_xi):
#      32 #     new_alt_params = optimize.fmin(mega_alt_xi, params, maxfun=1100)
# ---> 33     new_az_params = optimize.fmin(mega_az_xi, params, maxfun=1100)
#      34     return [new_az_params]
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     407             'initial_simplex': initial_simplex}
#     408
# --> 409     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     410     if full_output:
#     411         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     550
#     551     for k in range(N + 1):
# --> 552         fsim[k] = func(sim[k])
#     553
#     554     ind = numpy.argsort(fsim)
#
# c:\users\karlos\appdata\local\programs\python\python37-32\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# <ipython-input-112-263c11289320> in acumulate_xi(params)
#      21         suma_xi = 0
#      22         for x, y, z in zip(x_list, y_list, z_list):
# ---> 23             xi = construct_az_xi(int(x), int(y), int(z))
#      24             suma_xi += xi(C, A, F, V, S, D, P, Q, E, ep, float(X0), float(Y0), a0)
#      25         pbar.update()
#
# <ipython-input-51-d75031252e27> in construct_az_xi(x, y, z)
#      61
#      62 def construct_az_xi(x, y, z):
# ---> 63     def xi(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0):
#      64         az_teorico = construct_azimuth_deg(C, A, F, V, S, D, P, Q, E, ep, X0, Y0, a0)
#      65         return (z - az_teorico(x, y))**2
#
# KeyboardInterrupt:

# %%
result_5 = (0.048826087003725455, -0.021142174069559417, 0.32598730818211297,
             0.0682171007, 0.00310608468, -5.75141386e-05, 4.26865327e-06,
             -0.00415889519, -4.82552710e-03, -0.0022711518934522366, 7.28125200e+02,  4.78181845e+02, 7.73853421e-01)
plot_altura(result_5)
plot_azimuth(result_5)
